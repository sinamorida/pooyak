# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
info_1401 = pd.read_csv('1401_claean_info.csv')
info_1402 = pd.read_csv("1402_claean_info.csv")
info_1403 = pd.read_csv("1403_claean_info.csv")

# %%
monthly_usage_1401 = pd.read_csv('long_usage1401.csv')
monthly_usage_1402 = pd.read_csv("long_usage1402.csv")
monthly_usage_1403 = pd.read_csv("long_usage1403.csv")

# %%
info_1401.rename(columns=column_translations,inplace=True)
info_1402.rename(columns=column_translations,inplace=True)
info_1403.rename(columns=column_translations,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 info_1401.rename(columns=column_translations,inplace=True)
#       2 info_1402.rename(columns=column_translations,inplace=True)
#       3 info_1403.rename(columns=column_translations,inplace=True)
#
# NameError: name 'column_translations' is not defined

# %%
info_1401.drop(columns=["Unnamed: 0"],inplace=True)
info_1402.drop(columns=["Unnamed: 0"],inplace=True)
info_1403.drop(columns=["Unnamed: 0"],inplace=True)

# %%
monthly_usage_1401.drop(columns=["Unnamed: 0"],inplace=True)
monthly_usage_1402.drop(columns=["Unnamed: 0"],inplace=True)
monthly_usage_1403.drop(columns=["Unnamed: 0"],inplace=True)

# %%
info_1401
# Out:
#      Subscription Code License Type       County  Meter Serial  Meter Size  \
# 0               520009        صنعتی         مشهد  9.098011e+11        50.0
# 1               200654      کشاورزی        قوچان  9.098010e+11        80.0
# 2               622162      کشاورزی  تربت حیدریه  9.098011e+11        50.0
# 3               515618      کشاورزی         مشهد  9.098010e+11       125.0
# 4               529232      کشاورزی         مشهد  9.098010e+11       125.0
# ...                ...          ...          ...           ...         ...
# 2213            925247      کشاورزی        باخرز  9.098010e+11        50.0
# 2214            518473      کشاورزی         مشهد  9.098010e+11       100.0
# 2215            201250          NaN        قوچان  9.098010e+11        50.0
# 2216            925005      کشاورزی        باخرز  9.098010e+11       100.0
# 2217            102290          NaN       سبزوار  9.098011e+11       150.0
#
#      Installation Date   Last Connection Time  Consumption in Period (m³)  \
# 0           1402/11/15  1404/01/28 - 03:07:28                         NaN
# 1           1400/02/12  1404/01/28 - 02:08:15                   23879.930
# 2           1403/02/27  1403/09/08 - 03:10:09                         NaN
# 3           1400/02/30  1404/01/28 - 02:10:25                  103922.600
# 4           1401/06/23  1404/01/28 - 02:11:21                   84159.690
# ...                ...                    ...                         ...
# 2213        1400/03/24  1404/01/28 - 02:10:01                    5685.400
# 2214        1399/06/03  1404/01/28 - 03:01:20                  250173.700
# 2215        1399/07/07  1404/01/28 - 02:10:42                    8595.251
# 2216        1400/03/03  1403/07/29 - 02:04:50                  338274.800
# 2217        1402/12/15  1404/01/28 - 03:10:36                         NaN
#
#       Operating Hours in Period (h)  Average Flow Rate in Period (l/s)
# 0                               NaN                                NaN
# 1                          343575.4                               1.15
# 2                               NaN                                NaN
# 3                          475073.2                               6.91
# 4                           68022.1                               6.00
# ...                             ...                                ...
# 2213                        56574.8                               3.30
# 2214                       909533.1                              12.28
# 2215                         3673.9                               2.66
# 2216                       437856.7                              30.17
# 2217                            NaN                                NaN
#
# [2218 rows x 10 columns]

# %%
info_1401[info_1401['Average Flow Rate in Period (l/s)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Subscription Code, License Type, County, Meter Serial, Meter Size, Installation Date, Last Connection Time, Consumption in Period (m³), Operating Hours in Period (h), Average Flow Rate in Period (l/s)]
# Index: []

# %%
info_1401[info_1401['Average Flow Rate in Period (l/s)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Subscription Code, License Type, County, Meter Serial, Meter Size, Installation Date, Last Connection Time, Consumption in Period (m³), Operating Hours in Period (h), Average Flow Rate in Period (l/s)]
# Index: []

# %%
monthly_usage_1401.head()
# Out:
#   Subscription Code  Flow Rate (l/s)  Number of Negative Flows  \
# 0            520009              NaN                         0
# 1            200654             1.38                         0
# 2            622162              NaN                         0
# 3            515618             7.05                         0
# 4            529232              NaN                         0
#
#    Percentage of Negative Flows  Operating Hours (h)  Consumption (m³)  \
# 0                           0.0                  NaN               NaN
# 1                           0.0              16492.8           2727.77
# 2                           0.0                  NaN               NaN
# 3                           0.0              29319.6          14647.50
# 4                           0.0                  NaN               NaN
#
#    Number of Available Data Points  تعداد مورد انتظار  درصد اطلاعات موجود  \
# 0                                0                 31                 0.0
# 1                               31                 31               100.0
# 2                                0                 31                 0.0
# 3                               31                 31               100.0
# 4                                0                 31                 0.0
#
#      month
# 0  1401/01
# 1  1401/01
# 2  1401/01
# 3  1401/01
# 4  1401/01

# %%
monthly_usage_1401[monthly_usage_1401['Flow Rate (l/s)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Subscription Code, Flow Rate (l/s), Number of Negative Flows, Percentage of Negative Flows, Operating Hours (h), Consumption (m³), Number of Available Data Points, تعداد مورد انتظار, درصد اطلاعات موجود, month]
# Index: []

# %%
monthly_usage_1402[monthly_usage_1402['Flow Rate (l/s)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Subscription Code, Flow Rate (l/s), Number of Negative Flows, Percentage of Negative Flows, Operating Hours (h), Consumption (m³), Number of Available Data Points, تعداد مورد انتظار, درصد اطلاعات موجود, month]
# Index: []

# %%
monthly_usage_1403[monthly_usage_1403['Flow Rate (l/s)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Subscription Code, Flow Rate (l/s), Number of Negative Flows, Percentage of Negative Flows, Operating Hours (h), Consumption (m³), Number of Available Data Points, تعداد مورد انتظار, درصد اطلاعات موجود, month]
# Index: []

# %%
column_translations = {
    "Unnamed: 1_level_1" : 'Subscription Code',
    'کد اشتراک': 'Subscription Code',
    'نوع پروانه': 'License Type',
    'شهرستان': 'County',
    'سریال کنتور': 'Meter Serial',
    'سایز کنتور': 'Meter Size',
    'تاریخ نصب': 'Installation Date',
    'زمان آخرین اتصال': 'Last Connection Time',
    'مصرف بازه (m³)': 'Consumption in Period (m³)',
    'ساعت کارکرد بازه (h)': 'Operating Hours in Period (h)',
    'میانگین دبی بازه l/s': 'Average Flow Rate in Period (l/s)',
    'دبی l/s': 'Flow Rate (l/s)',
    'تعداد دبی منفی': 'Number of Negative Flows',
    'درصد دبی منفی': 'Percentage of Negative Flows',
    'ساعت کارکرد (h)': 'Operating Hours (h)',
    'مصرف (m³) (m³)': 'Consumption (m³)',
    'تعداد اطلاعات موجود': 'Number of Available Data Points',
}

# %%
info_1402.rename(columns=column_translations,inplace=True)

# %%
info_merged = pd.concat([info_1401,info_1402,info_1403])

# %%
monthly_usage_1401.drop(columns=['Unnamed: 0'],inplace=True)
monthly_usage_1402.drop(columns=['Unnamed: 0'],inplace=True)
monthly_usage_1403.drop(columns=['Unnamed: 0'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 monthly_usage_1401.drop(columns=['Unnamed: 0'],inplace=True)
#       2 monthly_usage_1402.drop(columns=['Unnamed: 0'],inplace=True)
#       3 monthly_usage_1403.drop(columns=['Unnamed: 0'],inplace=True)
#
# File ~/anaconda3/envs/tf-gpu/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/anaconda3/envs/tf-gpu/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/anaconda3/envs/tf-gpu/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/anaconda3/envs/tf-gpu/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
monthly_usage_1402
# Out:
#       Subscription Code  Flow Rate (l/s)  Number of Negative Flows  \
# 0                520009              NaN                         0
# 1                200654             0.97                         0
# 2                622162              NaN                         0
# 3                515618              NaN                         0
# 4                529232             5.10                         0
# ...                 ...              ...                       ...
# 26611            925247              NaN                         0
# 26612            518473              NaN                         0
# 26613            201250              NaN                         0
# 26614            925005            17.52                         0
# 26615            102290            37.49                         0
#
#        Percentage of Negative Flows  Operating Hours (h)  Consumption (m³)  \
# 0                               0.0                  NaN               NaN
# 1                               0.0             141127.1           2495.07
# 2                               0.0                  NaN               NaN
# 3                               0.0                  NaN               NaN
# 4                               0.0              31856.1          12316.66
# ...                             ...                  ...               ...
# 26611                           0.0                  0.0              0.00
# 26612                           0.0                  0.0               NaN
# 26613                           0.0                  NaN              0.00
# 26614                           0.0              22682.6            559.00
# 26615                           0.0                162.1          22652.78
#
#        Number of Available Data Points  تعداد مورد انتظار  درصد اطلاعات موجود  \
# 0                                    0                 31                 0.0
# 1                                   31                 31               100.0
# 2                                    0                 31                 0.0
# 3                                    0                 31                 0.0
# 4                                   31                 31               100.0
# ...                                ...                ...                 ...
# 26611                               29                 29               100.0
# 26612                               29                 29               100.0
# 26613                               29                 29               100.0
# 26614                               29                 29               100.0
# 26615                               29                 29               100.0
#
#          month
# 0      1402/01
# 1      1402/01
# 2      1402/01
# 3      1402/01
# 4      1402/01
# ...        ...
# 26611  1402/12
# 26612  1402/12
# 26613  1402/12
# 26614  1402/12
# 26615  1402/12
#
# [26616 rows x 10 columns]

# %%
monthly_usage_1403
# Out:
#       Subscription Code  Flow Rate (l/s)  Number of Negative Flows  \
# 0                520009             1.06                         0
# 1                200654             0.66                         0
# 2                622162              NaN                         0
# 3                515618              NaN                         0
# 4                529232              NaN                         0
# ...                 ...              ...                       ...
# 26611            925247              NaN                         0
# 26612            518473             5.44                         0
# 26613            201250              NaN                         0
# 26614            925005              NaN                         0
# 26615            102290            32.17                         0
#
#        Percentage of Negative Flows  Operating Hours (h)  Consumption (m³)  \
# 0                               0.0               2044.1           608.852
# 1                               0.0              51204.5           203.850
# 2                               0.0                  0.0             0.000
# 3                               0.0                  NaN               NaN
# 4                               0.0                  NaN               NaN
# ...                             ...                  ...               ...
# 26611                           0.0                  NaN               NaN
# 26612                           0.0                  9.8           177.140
# 26613                           0.0                  0.0             0.000
# 26614                           0.0                  NaN               NaN
# 26615                           0.0                  5.1           552.700
#
#        Number of Available Data Points  تعداد مورد انتظار  درصد اطلاعات موجود  \
# 0                                   31                 31              100.00
# 1                                   31                 31              100.00
# 2                                   11                 31               35.48
# 3                                    0                 31                0.00
# 4                                    0                 31                0.00
# ...                                ...                ...                 ...
# 26611                                0                 30                0.00
# 26612                               30                 30              100.00
# 26613                               30                 30              100.00
# 26614                                0                 30                0.00
# 26615                               30                 30              100.00
#
#          month
# 0      1403/01
# 1      1403/01
# 2      1403/01
# 3      1403/01
# 4      1403/01
# ...        ...
# 26611  1403/12
# 26612  1403/12
# 26613  1403/12
# 26614  1403/12
# 26615  1403/12
#
# [26616 rows x 10 columns]

# %%
usage_merged = pd.concat([monthly_usage_1401,monthly_usage_1402,monthly_usage_1403])

# %%
info_merged.to_csv("merged_info.csv")
usage_merged.to_csv("merged_usage.csv")

# %%
info_merged
# Out:
#      Subscription Code License Type       County  Meter Serial  Meter Size  \
# 0               520009        صنعتی         مشهد  9.098011e+11        50.0
# 1               200654      کشاورزی        قوچان  9.098010e+11        80.0
# 2               622162      کشاورزی  تربت حیدریه  9.098011e+11        50.0
# 3               515618      کشاورزی         مشهد  9.098010e+11       125.0
# 4               529232      کشاورزی         مشهد  9.098010e+11       125.0
# ...                ...          ...          ...           ...         ...
# 2213            925247      کشاورزی        باخرز  9.098010e+11        50.0
# 2214            518473      کشاورزی         مشهد  9.098010e+11       100.0
# 2215            201250          NaN        قوچان  9.098010e+11        50.0
# 2216            925005      کشاورزی        باخرز  9.098010e+11       100.0
# 2217            102290          NaN       سبزوار  9.098011e+11       150.0
#
#      Installation Date   Last Connection Time  Consumption in Period (m³)  \
# 0           1402/11/15  1404/01/28 - 03:07:28                         NaN
# 1           1400/02/12  1404/01/28 - 02:08:15                    23879.93
# 2           1403/02/27  1403/09/08 - 03:10:09                         NaN
# 3           1400/02/30  1404/01/28 - 02:10:25                   103922.60
# 4           1401/06/23  1404/01/28 - 02:11:21                    84159.69
# ...                ...                    ...                         ...
# 2213        1400/03/24  1404/01/28 - 02:10:01                        0.00
# 2214        1399/06/03  1404/01/28 - 03:01:20                    24042.14
# 2215        1399/07/07  1404/01/28 - 02:10:42                     5123.21
# 2216        1400/03/03  1403/07/29 - 02:04:50                   232348.00
# 2217        1402/12/15  1404/01/28 - 03:10:36                   229408.72
#
#       Operating Hours in Period (h)  Average Flow Rate in Period (l/s)
# 0                               NaN                                NaN
# 1                          343575.4                               1.15
# 2                               NaN                                NaN
# 3                          475073.2                               6.91
# 4                           68022.1                               6.00
# ...                             ...                                ...
# 2213                            0.0                                NaN
# 2214                         1431.8                               4.30
# 2215                          755.4                               2.01
# 2216                       144464.2                              20.80
# 2217                         1941.9                              32.37
#
# [6654 rows x 10 columns]

# %%
merge_inf0 = pd.read_csv("merged_info.csv")
merge_inf0.head()
# Out:
#    Unnamed: 0 Subscription Code License Type       County  Meter Serial  \
# 0           0            520009        صنعتی         مشهد  9.098011e+11
# 1           1            200654      کشاورزی        قوچان  9.098010e+11
# 2           2            622162      کشاورزی  تربت حیدریه  9.098011e+11
# 3           3            515618      کشاورزی         مشهد  9.098010e+11
# 4           4            529232      کشاورزی         مشهد  9.098010e+11
#
#    Meter Size Installation Date   Last Connection Time  \
# 0        50.0        1402/11/15  1404/01/28 - 03:07:28
# 1        80.0        1400/02/12  1404/01/28 - 02:08:15
# 2        50.0        1403/02/27  1403/09/08 - 03:10:09
# 3       125.0        1400/02/30  1404/01/28 - 02:10:25
# 4       125.0        1401/06/23  1404/01/28 - 02:11:21
#
#    Consumption in Period (m³)  Operating Hours in Period (h)  \
# 0                         NaN                            NaN
# 1                    23879.93                       343575.4
# 2                         NaN                            NaN
# 3                   103922.60                       475073.2
# 4                    84159.69                        68022.1
#
#    Average Flow Rate in Period (l/s)
# 0                                NaN
# 1                               1.15
# 2                                NaN
# 3                               6.91
# 4                               6.00

# %%
merge_inf0.isna().sum()
# Out:
# Unnamed: 0                              0
# Subscription Code                       0
# License Type                         1953
# County                                  0
# Meter Serial                            0
# Meter Size                              0
# Installation Date                       0
# Last Connection Time                  318
# Consumption in Period (m³)           1830
# Operating Hours in Period (h)        2139
# Average Flow Rate in Period (l/s)    2578
# dtype: int64

# %%
monthly_usage_1403
# Out:
#       Subscription Code  Flow Rate (l/s)  Number of Negative Flows  \
# 0                520009             1.06                         0
# 1                200654             0.66                         0
# 2                622162              NaN                         0
# 3                515618              NaN                         0
# 4                529232              NaN                         0
# ...                 ...              ...                       ...
# 26611            925247              NaN                         0
# 26612            518473             5.44                         0
# 26613            201250              NaN                         0
# 26614            925005              NaN                         0
# 26615            102290            32.17                         0
#
#        Percentage of Negative Flows  Operating Hours (h)  Consumption (m³)  \
# 0                               0.0               2044.1           608.852
# 1                               0.0              51204.5           203.850
# 2                               0.0                  0.0             0.000
# 3                               0.0                  NaN               NaN
# 4                               0.0                  NaN               NaN
# ...                             ...                  ...               ...
# 26611                           0.0                  NaN               NaN
# 26612                           0.0                  9.8           177.140
# 26613                           0.0                  0.0             0.000
# 26614                           0.0                  NaN               NaN
# 26615                           0.0                  5.1           552.700
#
#        Number of Available Data Points  تعداد مورد انتظار  درصد اطلاعات موجود  \
# 0                                   31                 31              100.00
# 1                                   31                 31              100.00
# 2                                   11                 31               35.48
# 3                                    0                 31                0.00
# 4                                    0                 31                0.00
# ...                                ...                ...                 ...
# 26611                                0                 30                0.00
# 26612                               30                 30              100.00
# 26613                               30                 30              100.00
# 26614                                0                 30                0.00
# 26615                               30                 30              100.00
#
#          month
# 0      1403/01
# 1      1403/01
# 2      1403/01
# 3      1403/01
# 4      1403/01
# ...        ...
# 26611  1403/12
# 26612  1403/12
# 26613  1403/12
# 26614  1403/12
# 26615  1403/12
#
# [26616 rows x 10 columns]

# %%
usage_merged
# Out:
#       Subscription Code  Flow Rate (l/s)  Number of Negative Flows  \
# 0                520009              NaN                         0
# 1                200654             1.38                         0
# 2                622162              NaN                         0
# 3                515618             7.05                         0
# 4                529232              NaN                         0
# ...                 ...              ...                       ...
# 26611            925247              NaN                         0
# 26612            518473             5.44                         0
# 26613            201250              NaN                         0
# 26614            925005              NaN                         0
# 26615            102290            32.17                         0
#
#        Percentage of Negative Flows  Operating Hours (h)  Consumption (m³)  \
# 0                               0.0                  NaN               NaN
# 1                               0.0              16492.8           2727.77
# 2                               0.0                  NaN               NaN
# 3                               0.0              29319.6          14647.50
# 4                               0.0                  NaN               NaN
# ...                             ...                  ...               ...
# 26611                           0.0                  NaN               NaN
# 26612                           0.0                  9.8            177.14
# 26613                           0.0                  0.0              0.00
# 26614                           0.0                  NaN               NaN
# 26615                           0.0                  5.1            552.70
#
#        Number of Available Data Points  تعداد مورد انتظار  درصد اطلاعات موجود  \
# 0                                    0                 31                 0.0
# 1                                   31                 31               100.0
# 2                                    0                 31                 0.0
# 3                                   31                 31               100.0
# 4                                    0                 31                 0.0
# ...                                ...                ...                 ...
# 26611                                0                 30                 0.0
# 26612                               30                 30               100.0
# 26613                               30                 30               100.0
# 26614                                0                 30                 0.0
# 26615                               30                 30               100.0
#
#          month
# 0      1401/01
# 1      1401/01
# 2      1401/01
# 3      1401/01
# 4      1401/01
# ...        ...
# 26611  1403/12
# 26612  1403/12
# 26613  1403/12
# 26614  1403/12
# 26615  1403/12
#
# [79848 rows x 10 columns]

# %%
usage_merged[usage_merged["Percentage of Negative Flows"] < 0]
# Out:
# Empty DataFrame
# Columns: [Subscription Code, Flow Rate (l/s), Number of Negative Flows, Percentage of Negative Flows, Operating Hours (h), Consumption (m³), Number of Available Data Points, تعداد مورد انتظار, درصد اطلاعات موجود, month]
# Index: []

# %%
df_neg_consumption = usage_merged[usage_merged["Consumption (m³)"] < 0]

# %%
df_neg_consumption
# Out:
#       Subscription Code  Flow Rate (l/s)  Number of Negative Flows  \
# 32               302041              NaN                         0
# 57               516231              NaN                         0
# 275              515534              NaN                         0
# 652              529336             2.07                         1
# 692              518586              NaN                         0
# ...                 ...              ...                       ...
# 26401            516014              NaN                         0
# 26474            608600              NaN                         0
# 26475            804911              NaN                         0
# 26493            514691             4.43                         0
# 26585            103209              NaN                         0
#
#        Percentage of Negative Flows  Operating Hours (h)  Consumption (m³)  \
# 32                             0.00                  0.0            -2.600
# 57                             0.00                  NaN            -0.052
# 275                            0.00                  0.0            -0.133
# 652                            3.23                300.4       -180119.900
# 692                            0.00                  0.0           -37.900
# ...                             ...                  ...               ...
# 26401                          0.00                  0.0            -0.120
# 26474                          0.00                  0.0            -0.003
# 26475                          0.00                  0.0            -0.003
# 26493                          0.00                270.3      -1089970.393
# 26585                          0.00                  0.0            -0.046
#
#        Number of Available Data Points  تعداد مورد انتظار  درصد اطلاعات موجود  \
# 32                                  31                 31              100.00
# 57                                  12                 31               38.71
# 275                                 31                 31              100.00
# 652                                 10                 31               32.26
# 692                                 31                 31              100.00
# ...                                ...                ...                 ...
# 26401                               30                 30              100.00
# 26474                               30                 30              100.00
# 26475                               30                 30              100.00
# 26493                               15                 30               50.00
# 26585                               30                 30              100.00
#
#          month
# 32     1401/01
# 57     1401/01
# 275    1401/01
# 652    1401/01
# 692    1401/01
# ...        ...
# 26401  1403/12
# 26474  1403/12
# 26475  1403/12
# 26493  1403/12
# 26585  1403/12
#
# [3545 rows x 10 columns]

# %%
numerical_cols_for_desc = ['Flow Rate (l/s)', 'Operating Hours (h)', 'Consumption (m³)',
                           'Number of Negative Flows']

# %%
df_neg_flow =  usage_merged[usage_merged["Number of Negative Flows"] > 0]

# %%
sumation_for_3years =  usage_merged.groupby("Subscription Code").sum()

# %%
mean_for_3years =  usage_merged.groupby("Subscription Code",dropna=True)[numerical_cols_for_desc].mean()

# %%
mean_for_3years
# Out:
#                             Flow Rate (l/s)  Operating Hours (h)  \
# Subscription Code
#  تبادل چاه شماره 6                 6.996667         46598.400000
# 0000297                                 NaN             0.000000
# 000134                                  NaN             0.000000
# 000159                                  NaN             0.000000
# 000163                                  NaN             0.000000
# ...                                     ...                  ...
# کلانتری 16 موتورخانه فاز3               NaN                  NaN
# کوثر شمالی 8 بوستان پرنیان              NaN                  NaN
# کوی کارمندان                            NaN                  NaN
# ۴۰۰۹۷۲۴۴                                NaN             0.000000
# ۶۰۳۱۶۴                            16.995000            66.766667
#
#                             Consumption (m³)  Number of Negative Flows
# Subscription Code
#  تبادل چاه شماره 6               7149.098182                  0.055556
# 0000297                           274.834917                  0.000000
# 000134                            629.802385                  0.000000
# 000159                           1199.628000                  0.000000
# 000163                            312.825923                  0.000000
# ...                                      ...                       ...
# کلانتری 16 موتورخانه فاز3                NaN                  0.000000
# کوثر شمالی 8 بوستان پرنیان               NaN                  0.000000
# کوی کارمندان                             NaN                  0.000000
# ۴۰۰۹۷۲۴۴                           -8.609000                  0.000000
# ۶۰۳۱۶۴                           3941.523667                  0.000000
#
# [2201 rows x 4 columns]

# %%
df_neg_consumption
# Out:
#       Subscription Code  Flow Rate (l/s)  Number of Negative Flows  \
# 32               302041              NaN                         0
# 57               516231              NaN                         0
# 275              515534              NaN                         0
# 652              529336             2.07                         1
# 692              518586              NaN                         0
# ...                 ...              ...                       ...
# 26401            516014              NaN                         0
# 26474            608600              NaN                         0
# 26475            804911              NaN                         0
# 26493            514691             4.43                         0
# 26585            103209              NaN                         0
#
#        Percentage of Negative Flows  Operating Hours (h)  Consumption (m³)  \
# 32                             0.00                  0.0            -2.600
# 57                             0.00                  NaN            -0.052
# 275                            0.00                  0.0            -0.133
# 652                            3.23                300.4       -180119.900
# 692                            0.00                  0.0           -37.900
# ...                             ...                  ...               ...
# 26401                          0.00                  0.0            -0.120
# 26474                          0.00                  0.0            -0.003
# 26475                          0.00                  0.0            -0.003
# 26493                          0.00                270.3      -1089970.393
# 26585                          0.00                  0.0            -0.046
#
#        Number of Available Data Points  تعداد مورد انتظار  درصد اطلاعات موجود  \
# 32                                  31                 31              100.00
# 57                                  12                 31               38.71
# 275                                 31                 31              100.00
# 652                                 10                 31               32.26
# 692                                 31                 31              100.00
# ...                                ...                ...                 ...
# 26401                               30                 30              100.00
# 26474                               30                 30              100.00
# 26475                               30                 30              100.00
# 26493                               15                 30               50.00
# 26585                               30                 30              100.00
#
#          month
# 32     1401/01
# 57     1401/01
# 275    1401/01
# 652    1401/01
# 692    1401/01
# ...        ...
# 26401  1403/12
# 26474  1403/12
# 26475  1403/12
# 26493  1403/12
# 26585  1403/12
#
# [3545 rows x 10 columns]

# %%
df_neg_consumption.to_csv("negative_cons_in_3years.csv")

# %%
non_negatives_cons = usage_merged[usage_merged["Consumption (m³)"] >= 0]

# %%
usage_merged[usage_merged["Operating Hours (h)"] < 0]
# Out:
#      Subscription Code  Flow Rate (l/s)  Number of Negative Flows  \
# 4174            541975             0.48                         3
#
#       Percentage of Negative Flows  Operating Hours (h)  Consumption (m³)  \
# 4174                          9.68              -2207.8            -80.01
#
#       Number of Available Data Points  تعداد مورد انتظار  درصد اطلاعات موجود  \
# 4174                                7                 31               22.58
#
#         month
# 4174  1401/02

# %%
non_negatives_cons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43536 entries, 1 to 26615
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Subscription Code                43536 non-null  object
#  1   Flow Rate (l/s)                  32752 non-null  float64
#  2   Number of Negative Flows         43536 non-null  int64
#  3   Percentage of Negative Flows     43536 non-null  float64
#  4   Operating Hours (h)              37493 non-null  float64
#  5   Consumption (m³)                 43536 non-null  float64
#  6   Number of Available Data Points  43536 non-null  int64
#  7   تعداد مورد انتظار                43536 non-null  int64
#  8   درصد اطلاعات موجود               43536 non-null  float64
#  9   month                            43536 non-null  object
# dtypes: float64(5), int64(3), object(2)
# memory usage: 3.7+ MB

# %%
non_negatives_cons
# Out:
#       Subscription Code  Flow Rate (l/s)  Number of Negative Flows  \
# 1                200654             1.38                         0
# 3                515618             7.05                         0
# 6                805816             3.06                         0
# 7                603182              NaN                         0
# 10               517963            17.72                         0
# ...                 ...              ...                       ...
# 26609            516081             2.33                         0
# 26610            514250            11.36                         0
# 26612            518473             5.44                         0
# 26613            201250              NaN                         0
# 26615            102290            32.17                         0
#
#        Percentage of Negative Flows  Operating Hours (h)  Consumption (m³)  \
# 1                               0.0              16492.8          2727.770
# 3                               0.0              29319.6         14647.500
# 6                               0.0              10209.3           597.709
# 7                               0.0                  NaN             0.000
# 10                              0.0             126871.1         39863.500
# ...                             ...                  ...               ...
# 26609                           0.0                 12.9           137.000
# 26610                           0.0                 58.1          2652.420
# 26612                           0.0                  9.8           177.140
# 26613                           0.0                  0.0             0.000
# 26615                           0.0                  5.1           552.700
#
#        Number of Available Data Points  تعداد مورد انتظار  درصد اطلاعات موجود  \
# 1                                   31                 31               100.0
# 3                                   31                 31               100.0
# 6                                   31                 31               100.0
# 7                                   31                 31               100.0
# 10                                  31                 31               100.0
# ...                                ...                ...                 ...
# 26609                               30                 30               100.0
# 26610                               30                 30               100.0
# 26612                               30                 30               100.0
# 26613                               30                 30               100.0
# 26615                               30                 30               100.0
#
#          month
# 1      1401/01
# 3      1401/01
# 6      1401/01
# 7      1401/01
# 10     1401/01
# ...        ...
# 26609  1403/12
# 26610  1403/12
# 26612  1403/12
# 26613  1403/12
# 26615  1403/12
#
# [43536 rows x 10 columns]

# %%
farmers = info_1401[info_1401["License Type"] == "کشاورزی"][['Subscription Code','County','Meter Size','Last Connection Time']]

# %%
farmers
# Out:
#      Subscription Code       County  Meter Size   Last Connection Time
# 1               200654        قوچان        80.0  1404/01/28 - 02:08:15
# 2               622162  تربت حیدریه        50.0  1403/09/08 - 03:10:09
# 3               515618         مشهد       125.0  1404/01/28 - 02:10:25
# 4               529232         مشهد       125.0  1404/01/28 - 02:11:21
# 8               514013         مشهد       150.0  1404/01/28 - 03:11:00
# ...                ...          ...         ...                    ...
# 2211            516081         مشهد       150.0  1404/01/28 - 03:10:38
# 2212            514250         مشهد       100.0  1404/01/28 - 03:08:27
# 2213            925247        باخرز        50.0  1404/01/28 - 02:10:01
# 2214            518473         مشهد       100.0  1404/01/28 - 03:01:20
# 2216            925005        باخرز       100.0  1403/07/29 - 02:04:50
#
# [1009 rows x 4 columns]

# %%
info_1401
# Out:
#      Subscription Code License Type       County  Meter Serial  Meter Size  \
# 0               520009        صنعتی         مشهد  9.098011e+11        50.0
# 1               200654      کشاورزی        قوچان  9.098010e+11        80.0
# 2               622162      کشاورزی  تربت حیدریه  9.098011e+11        50.0
# 3               515618      کشاورزی         مشهد  9.098010e+11       125.0
# 4               529232      کشاورزی         مشهد  9.098010e+11       125.0
# ...                ...          ...          ...           ...         ...
# 2213            925247      کشاورزی        باخرز  9.098010e+11        50.0
# 2214            518473      کشاورزی         مشهد  9.098010e+11       100.0
# 2215            201250          NaN        قوچان  9.098010e+11        50.0
# 2216            925005      کشاورزی        باخرز  9.098010e+11       100.0
# 2217            102290          NaN       سبزوار  9.098011e+11       150.0
#
#      Installation Date   Last Connection Time  Consumption in Period (m³)  \
# 0           1402/11/15  1404/01/28 - 03:07:28                         NaN
# 1           1400/02/12  1404/01/28 - 02:08:15                   23879.930
# 2           1403/02/27  1403/09/08 - 03:10:09                         NaN
# 3           1400/02/30  1404/01/28 - 02:10:25                  103922.600
# 4           1401/06/23  1404/01/28 - 02:11:21                   84159.690
# ...                ...                    ...                         ...
# 2213        1400/03/24  1404/01/28 - 02:10:01                    5685.400
# 2214        1399/06/03  1404/01/28 - 03:01:20                  250173.700
# 2215        1399/07/07  1404/01/28 - 02:10:42                    8595.251
# 2216        1400/03/03  1403/07/29 - 02:04:50                  338274.800
# 2217        1402/12/15  1404/01/28 - 03:10:36                         NaN
#
#       Operating Hours in Period (h)  Average Flow Rate in Period (l/s)
# 0                               NaN                                NaN
# 1                          343575.4                               1.15
# 2                               NaN                                NaN
# 3                          475073.2                               6.91
# 4                           68022.1                               6.00
# ...                             ...                                ...
# 2213                        56574.8                               3.30
# 2214                       909533.1                              12.28
# 2215                         3673.9                               2.66
# 2216                       437856.7                              30.17
# 2217                            NaN                                NaN
#
# [2218 rows x 10 columns]

# %% [markdown]
# کنتور های خانگی

# %%
houses = info_1401[info_1401["Meter Serial"] >= 920000000000]

# %%
not_houses =  info_1401[info_1401["Meter Serial"] < 920000000000]

# %%
not_houses
# Out:
#      Subscription Code License Type       County  Meter Serial  Meter Size  \
# 0               520009        صنعتی         مشهد  9.098011e+11        50.0
# 1               200654      کشاورزی        قوچان  9.098010e+11        80.0
# 2               622162      کشاورزی  تربت حیدریه  9.098011e+11        50.0
# 3               515618      کشاورزی         مشهد  9.098010e+11       125.0
# 4               529232      کشاورزی         مشهد  9.098010e+11       125.0
# ...                ...          ...          ...           ...         ...
# 2213            925247      کشاورزی        باخرز  9.098010e+11        50.0
# 2214            518473      کشاورزی         مشهد  9.098010e+11       100.0
# 2215            201250          NaN        قوچان  9.098010e+11        50.0
# 2216            925005      کشاورزی        باخرز  9.098010e+11       100.0
# 2217            102290          NaN       سبزوار  9.098011e+11       150.0
#
#      Installation Date   Last Connection Time  Consumption in Period (m³)  \
# 0           1402/11/15  1404/01/28 - 03:07:28                         NaN
# 1           1400/02/12  1404/01/28 - 02:08:15                   23879.930
# 2           1403/02/27  1403/09/08 - 03:10:09                         NaN
# 3           1400/02/30  1404/01/28 - 02:10:25                  103922.600
# 4           1401/06/23  1404/01/28 - 02:11:21                   84159.690
# ...                ...                    ...                         ...
# 2213        1400/03/24  1404/01/28 - 02:10:01                    5685.400
# 2214        1399/06/03  1404/01/28 - 03:01:20                  250173.700
# 2215        1399/07/07  1404/01/28 - 02:10:42                    8595.251
# 2216        1400/03/03  1403/07/29 - 02:04:50                  338274.800
# 2217        1402/12/15  1404/01/28 - 03:10:36                         NaN
#
#       Operating Hours in Period (h)  Average Flow Rate in Period (l/s)
# 0                               NaN                                NaN
# 1                          343575.4                               1.15
# 2                               NaN                                NaN
# 3                          475073.2                               6.91
# 4                           68022.1                               6.00
# ...                             ...                                ...
# 2213                        56574.8                               3.30
# 2214                       909533.1                              12.28
# 2215                         3673.9                               2.66
# 2216                       437856.7                              30.17
# 2217                            NaN                                NaN
#
# [2068 rows x 10 columns]

# %%
houses
# Out:
#      Subscription Code License Type County  Meter Serial  Meter Size  \
# 141             479654          NaN   مشهد  9.298010e+11        15.0
# 142             917062          NaN   مشهد  9.298010e+11        15.0
# 143             319197          NaN   مشهد  9.298010e+11        15.0
# 144             560142          NaN   مشهد  9.298010e+11        15.0
# 145           ۴۰۰۹۷۲۴۴          NaN   مشهد  9.298010e+11        15.0
# ...                ...          ...    ...           ...         ...
# 2192          14211140          NaN    خرو  9.298010e+11        20.0
# 2195          14211368          NaN    خرو  9.298010e+11        40.0
# 2197          02019010          NaN   کلات  9.298010e+11        25.0
# 2199          14211211          NaN    خرو  9.298010e+11        25.0
# 2204          14211107          NaN    خرو  9.298010e+11        20.0
#
#      Installation Date   Last Connection Time  Consumption in Period (m³)  \
# 141         1403/07/29  1404/01/27 - 13:48:52                         NaN
# 142         1403/07/14  1404/01/27 - 13:54:41                         NaN
# 143         1403/12/29  1404/01/28 - 14:18:19                         NaN
# 144         1403/07/28  1404/01/25 - 13:51:53                         NaN
# 145         1403/07/14  1404/01/27 - 13:37:26                         NaN
# ...                ...                    ...                         ...
# 2192        1402/12/20  1404/01/27 - 13:52:49                         NaN
# 2195        1403/10/01  1404/01/27 - 13:53:25                         NaN
# 2197        1403/11/03  1404/01/27 - 13:53:28                         NaN
# 2199        1403/02/01  1404/01/23 - 13:40:30                         NaN
# 2204        1402/10/23  1404/01/27 - 13:55:25                         NaN
#
#       Operating Hours in Period (h)  Average Flow Rate in Period (l/s)
# 141                             NaN                                NaN
# 142                             NaN                                NaN
# 143                             NaN                                NaN
# 144                             NaN                                NaN
# 145                             NaN                                NaN
# ...                             ...                                ...
# 2192                            NaN                                NaN
# 2195                            NaN                                NaN
# 2197                            NaN                                NaN
# 2199                            NaN                                NaN
# 2204                            NaN                                NaN
#
# [150 rows x 10 columns]

# %%
from numpy import isin


houses_usage_in_3years = usage_merged[usage_merged['Subscription Code'].isin( houses["Subscription Code"])]

# %%
houses_usage_in_3years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5400 entries, 141 to 26602
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Subscription Code                5400 non-null   object
#  1   Flow Rate (l/s)                  0 non-null      float64
#  2   Number of Negative Flows         5400 non-null   int64
#  3   Percentage of Negative Flows     5400 non-null   float64
#  4   Operating Hours (h)              1294 non-null   float64
#  5   Consumption (m³)                 1371 non-null   float64
#  6   Number of Available Data Points  5400 non-null   int64
#  7   تعداد مورد انتظار                5400 non-null   int64
#  8   درصد اطلاعات موجود               5400 non-null   float64
#  9   month                            5400 non-null   object
# dtypes: float64(5), int64(3), object(2)
# memory usage: 464.1+ KB

# %%
houses_usage_in_3years[numerical_cols_for_desc].describe()
# Out:
#        Flow Rate (l/s)  Operating Hours (h)  Consumption (m³)  \
# count              0.0               1294.0       1371.000000
# mean               NaN                  0.0        434.801807
# std                NaN                  0.0       5236.418717
# min                NaN                  0.0     -34504.110000
# 25%                NaN                  0.0          0.000000
# 50%                NaN                  0.0          4.356000
# 75%                NaN                  0.0        168.311500
# max                NaN                  0.0     175778.824000
#
#        Number of Negative Flows
# count                    5400.0
# mean                        0.0
# std                         0.0
# min                         0.0
# 25%                         0.0
# 50%                         0.0
# 75%                         0.0
# max                         0.0

# %% [markdown]
# looks like no valid info exists in houses meter dataset

# %%
usage_without_houses =  usage_merged[usage_merged['Subscription Code'].isin(not_houses["Subscription Code"])]

# %% [markdown]
# the above df is all records except house's meters
