# %%
import numpy as np 
import pandas as pd

# %%
# %ls
# Out:
#  notebook.ipynb  'Water demand data set 2_Unit_MLD.xlsx'  'خروجی مخزن.xlsx'
#  outflow.xlsx    'چاه -سریال کنتور909801033515.xlsx'       خزاما.xlsx

# %%
df_outflow = pd.read_excel("outflow.xlsx")
df_tank = pd.read_excel("خروجی مخزن.xlsx")
df_water_deamand = pd.read_excel("Water demand data set 2_Unit_MLD.xlsx",header=None)
df_unknow = pd.read_excel("چاه -سریال کنتور909801033515.xlsx")

# %%
df_outflow.head()
# Out:
#   DATE         DATE        .1 TIME              ClusterEO.T_R1AI_OutFlow1   \
# 0   2016-09-27     2016-09-27         23:56:36  n/a
# 1   2016-09-28     2016-09-28         00:04:48  n/a
# 2   2016-09-28     2016-09-28         00:13:00  n/a
# 3   2016-09-28     2016-09-28         00:21:12  n/a
# 4   2016-09-28     2016-09-28         00:29:24  n/a
#
#    ClusterEO.T_R1AI_Level2   ClusterEO.T_R1AI_Chlorine
# 0  n/a                       n/a
# 1  n/a                       n/a
# 2  n/a                       n/a
# 3  n/a                       n/a
# 4  n/a                       n/a

# %%
df_outflow['ClusterEO.T_R1AI_Chlorine '].value_counts()
# Out:
# ClusterEO.T_R1AI_Chlorine
# n/a                           861
# 0                             231
# 5                             189
# 0.82322                        70
# 0.82719                        69
#                              ...
# 0.89601                         1
# 0.88416                         1
# 0.71388                         1
# 0.55925                         1
# 0.67458                         1
# Name: count, Length: 18154, dtype: int64

# %%
df_outflow
# Out:
#       DATE         DATE        .1 TIME              \
# 0       2016-09-27     2016-09-27         23:56:36
# 1       2016-09-28     2016-09-28         00:04:48
# 2       2016-09-28     2016-09-28         00:13:00
# 3       2016-09-28     2016-09-28         00:21:12
# 4       2016-09-28     2016-09-28         00:29:24
# ...            ...            ...              ...
# 64968   2017-10-02     2017-10-02         23:02:37
# 64969   2017-10-02     2017-10-02         23:10:49
# 64970   2017-10-02     2017-10-02         23:19:01
# 64971   2017-10-02     2017-10-02         23:27:13
# 64972   2017-10-02     2017-10-02         23:35:25
#
#        ClusterEO.T_R1AI_OutFlow1   ClusterEO.T_R1AI_Level2   \
# 0      n/a                         n/a
# 1      n/a                         n/a
# 2      n/a                         n/a
# 3      n/a                         n/a
# 4      n/a                         n/a
# ...                           ...                       ...
# ...

# %%
df_tank.head()
# Out:
#                    تاریخ دبی (Lit/s) مصرف روزانه (m³) ساعت کارکرد روزانه (h)  \
# 0  1402/02/05 - 23:59:59        22.1         27414.91                  344.6
# 1  1402/02/06 - 23:59:59        19.8          1710.09                     64
# 2  1402/02/07 - 23:59:59        21.5          1856.97                  400.3
# 3  1402/02/08 - 23:59:59        21.4          1849.33                   25.9
# 4  1402/02/09 - 23:59:59        22.4          1939.77                      5
#
#    سهمیه باقیمانده (m³)
# 0             -27384.74
# 1             -29093.41
# 2             -30949.13
# 3             -32798.75
# 4             -34739.42

# %%
df_water_deamand.head()
# Out:
#          0           1           2           3           4           5     \
# 0  108.811323  123.998979  133.331252  142.121897  138.773395  147.506628
#
#          6           7           8           9     ...        7286  \
# 0  165.495164  142.419681  113.582504  106.928717  ...  109.069046
#
#          7287        7288        7289        7290        7291        7292  \
# 0  108.384835  112.310925  122.009436  130.751186  121.705342  105.903189
#
#         7293       7294       7295
# 0  86.954423  70.825465  91.368515
#
# [1 rows x 7296 columns]

# %%
df_water_deamand.T
# Out:
#                0
# 0     108.811323
# 1     123.998979
# 2     133.331252
# 3     142.121897
# 4     138.773395
# ...          ...
# 7291  121.705342
# 7292  105.903189
# 7293   86.954423
# 7294   70.825465
# 7295   91.368515
#
# [7296 rows x 1 columns]

# %% [markdown]
# remember to ask some question about the above dataset

# %%
df_water_deamand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Columns: 7296 entries, 0 to 7295
# dtypes: float64(7296)
# memory usage: 57.1 KB

# %%
df_outflow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64973 entries, 0 to 64972
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DATE                        64973 non-null  datetime64[ns]
#  1   DATE        .1              64973 non-null  datetime64[ns]
#  2   TIME                        64973 non-null  object
#  3   ClusterEO.T_R1AI_OutFlow1   64973 non-null  object
#  4   ClusterEO.T_R1AI_Level2     64973 non-null  object
#  5   ClusterEO.T_R1AI_Chlorine   64973 non-null  object
# dtypes: datetime64[ns](2), object(4)
# memory usage: 3.0+ MB

# %%
df_tank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   تاریخ                   199 non-null    object
#  1   دبی (Lit/s)             200 non-null    object
#  2   مصرف روزانه (m³)        199 non-null    object
#  3   ساعت کارکرد روزانه (h)  199 non-null    object
#  4   سهمیه باقیمانده (m³)    198 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 7.9+ KB

# %%
df_unknow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1315 entries, 0 to 1314
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   تاریخ                   1314 non-null   object
#  1   دبی (Lit/s)             1272 non-null   object
#  2   مصرف روزانه (m³)        1271 non-null   object
#  3   ساعت کارکرد روزانه (h)  778 non-null    object
#  4   سهمیه باقیمانده (m³)    1309 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 51.5+ KB

# %%
df_unknow.head()
# Out:
#                    تاریخ دبی (Lit/s) مصرف روزانه (m³) ساعت کارکرد روزانه (h)  \
# 0  1399/09/12 - 23:59:59           0             1.89                      0
# 1  1399/09/13 - 23:59:59           0                0                      0
# 2  1399/09/14 - 23:59:59           0            0.946                      0
# 3  1399/09/15 - 23:59:59           0                0                      0
# 4  1399/09/16 - 23:59:59           0                0                      0
#
#    سهمیه باقیمانده (m³)
# 0              39998.11
# 1              39998.11
# 2              39997.16
# 3              39997.16
# 4              39997.16

# %% [markdown]
# هدف :
# پیشبینی مصرف برای تعداد مختلف کنتور و یا یک کنتور
# هردو لازمه
# با گام های زمانی متفاوت
