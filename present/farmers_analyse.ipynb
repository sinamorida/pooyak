# %%
import pandas as pd

# %%
farmers = pd.read_csv("farmers_meter_info.csv")

# %%
farmers
# Out:
#       Subscription Code License Type       County  Meter Serial  Meter Size  \
# 0                200654      کشاورزی        قوچان  9.098010e+11        80.0
# 1                622162      کشاورزی  تربت حیدریه  9.098011e+11        50.0
# 2                515618      کشاورزی         مشهد  9.098010e+11       125.0
# 3                529232      کشاورزی         مشهد  9.098010e+11       125.0
# 4                514013      کشاورزی         مشهد  9.098011e+11       150.0
# ...                 ...          ...          ...           ...         ...
# 1004             516081      کشاورزی         مشهد  9.098010e+11       150.0
# 1005             514250      کشاورزی         مشهد  9.098010e+11       100.0
# 1006             925247      کشاورزی        باخرز  9.098010e+11        50.0
# 1007             518473      کشاورزی         مشهد  9.098010e+11       100.0
# 1008             925005      کشاورزی        باخرز  9.098010e+11       100.0
#
# ...
